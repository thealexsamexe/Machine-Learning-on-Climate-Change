# %% [markdown]
# Importing the dataset

# %%
import pandas as pd
df = pd.read_csv ('emission data.csv')

# %% [markdown]
# Checking the Null values

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# Reading the DataFrame

# %%
df
# Out:
#                        Country     1751      1752      1753      1754  \
# 0                  Afghanistan        0         0         0         0
# 1                       Africa        0         0         0         0
# 2                      Albania        0         0         0         0
# 3                      Algeria        0         0         0         0
# 4             Americas (other)        0         0         0         0
# ..                         ...      ...       ...       ...       ...
# 226  Wallis and Futuna Islands        0         0         0         0
# 227                      World  9350528  18704720  28058912  37416768
# 228                      Yemen        0         0         0         0
# 229                     Zambia        0         0         0         0
# 230                   Zimbabwe        0         0         0         0
#
#          1755      1756      1757      1758      1759  ...          2008  \
# ...

# %% [markdown]
# Exporting the csv file as 'cleaned emission data.csv'

# %%
df.to_csv('cleaned emission data.csv',index=False)

# %% [markdown]
# Checking the csv file if there is changes or not and reading the dataFrame

# %%
import pandas as pd
df1= pd.read_csv ('emission data.csv')
df1
# Out:
#                        Country     1751      1752      1753      1754  \
# 0                  Afghanistan        0         0         0         0
# 1                       Africa        0         0         0         0
# 2                      Albania        0         0         0         0
# 3                      Algeria        0         0         0         0
# 4             Americas (other)        0         0         0         0
# ..                         ...      ...       ...       ...       ...
# 226  Wallis and Futuna Islands        0         0         0         0
# 227                      World  9350528  18704720  28058912  37416768
# 228                      Yemen        0         0         0         0
# 229                     Zambia        0         0         0         0
# 230                   Zimbabwe        0         0         0         0
#
#          1755      1756      1757      1758      1759  ...          2008  \
# ...
