# %% [markdown]
# Importing the csv file and reading the dataframe

# %%
import pandas as pd
df6 = pd.read_csv('annual-change-forest-area.csv')
df6
# Out:
#         Entity Code  Year  Net forest conversion
# 0      Algeria  DZA  1990                -8800.0
# 1      Algeria  DZA  2000                33900.0
# 2      Algeria  DZA  2010                 7600.0
# 3      Algeria  DZA  2015                -1400.0
# 4    Argentina  ARG  1990              -182600.0
# ..         ...  ...   ...                    ...
# 470     Zambia  ZMB  2015              -188210.0
# 471   Zimbabwe  ZWE  1990               -46070.0
# 472   Zimbabwe  ZWE  2000               -46070.0
# 473   Zimbabwe  ZWE  2010               -46070.0
# 474   Zimbabwe  ZWE  2015               -46070.0
#
# [475 rows x 4 columns]

# %% [markdown]
# Renaming the column 'Entity' as 'Country'

# %%
df6.rename(columns = {'Entity': 'Country'}, inplace = True)

# %% [markdown]
# Reading the DataFrame

# %%
df6
# Out:
#        Country Code  Year  Net forest conversion
# 0      Algeria  DZA  1990                -8800.0
# 1      Algeria  DZA  2000                33900.0
# 2      Algeria  DZA  2010                 7600.0
# 3      Algeria  DZA  2015                -1400.0
# 4    Argentina  ARG  1990              -182600.0
# ..         ...  ...   ...                    ...
# 470     Zambia  ZMB  2015              -188210.0
# 471   Zimbabwe  ZWE  1990               -46070.0
# 472   Zimbabwe  ZWE  2000               -46070.0
# 473   Zimbabwe  ZWE  2010               -46070.0
# 474   Zimbabwe  ZWE  2015               -46070.0
#
# [475 rows x 4 columns]

# %% [markdown]
# Renaming the column 'Net forest conversion' as 'Net change'

# %%
df6.rename(columns = {'Net forest conversion': 'Net change'}, inplace = True)

# %% [markdown]
# Reading the DataFrame

# %%
df6
# Out:
#        Country Code  Year  Net change
# 0      Algeria  DZA  1990     -8800.0
# 1      Algeria  DZA  2000     33900.0
# 2      Algeria  DZA  2010      7600.0
# 3      Algeria  DZA  2015     -1400.0
# 4    Argentina  ARG  1990   -182600.0
# ..         ...  ...   ...         ...
# 470     Zambia  ZMB  2015   -188210.0
# 471   Zimbabwe  ZWE  1990    -46070.0
# 472   Zimbabwe  ZWE  2000    -46070.0
# 473   Zimbabwe  ZWE  2010    -46070.0
# 474   Zimbabwe  ZWE  2015    -46070.0
#
# [475 rows x 4 columns]

# %% [markdown]
# Checking the present of null values

# %%
df6.isnull().sum().sum()
# Out:
# 8

# %% [markdown]
# To check how many columns have null values

# %%
df6.isnull().sum(axis = 0)
# Out:
# Country       0
# Code          8
# Year          0
# Net change    0
# dtype: int64

# %% [markdown]
# To check how many rows have null values

# %%
df6.isnull().sum(axis = 1)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 470    0
# 471    0
# 472    0
# 473    0
# 474    0
# Length: 475, dtype: int64

# %% [markdown]
# To display all the rows and columns of dataset

# %%
pd.set_option('display.max_rows', 475)

# %% [markdown]
# Reading the DataFrame

# %%
df6
# Out:
#                       Country      Code  Year  Net change
# 0                     Algeria       DZA  1990     -8800.0
# 1                     Algeria       DZA  2000     33900.0
# 2                     Algeria       DZA  2010      7600.0
# 3                     Algeria       DZA  2015     -1400.0
# 4                   Argentina       ARG  1990   -182600.0
# 5                   Argentina       ARG  2000   -316400.0
# 6                   Argentina       ARG  2010   -223400.0
# 7                   Argentina       ARG  2015   -104800.0
# 8                       Aruba       ABW  1990         0.0
# 9                       Aruba       ABW  2000         0.0
# 10                      Aruba       ABW  2010         0.0
# 11                      Aruba       ABW  2015         0.0
# 12                  Australia       AUS  1990   -206810.0
# 13                  Australia       AUS  2000   -226800.0
# 14                  Australia       AUS  2010    709680.0
# ...

# %% [markdown]
# Slicing the rows

# %%
df6[136:140]
# Out:
#            Country Code  Year  Net change
# 136  Faroe Islands  NaN  1990         0.0
# 137  Faroe Islands  NaN  2000         0.0
# 138  Faroe Islands  NaN  2010         0.0
# 139  Faroe Islands  NaN  2015         0.0

# %% [markdown]
# Importing the values 'DNK' to column 'Code' from the above slice rows

# %%
df6.loc[136:140, ['Code']] = 'DNK'

# %% [markdown]
# Reading the DataFrame

# %%
df6
# Out:
#                       Country      Code  Year  Net change
# 0                     Algeria       DZA  1990     -8800.0
# 1                     Algeria       DZA  2000     33900.0
# 2                     Algeria       DZA  2010      7600.0
# 3                     Algeria       DZA  2015     -1400.0
# 4                   Argentina       ARG  1990   -182600.0
# 5                   Argentina       ARG  2000   -316400.0
# 6                   Argentina       ARG  2010   -223400.0
# 7                   Argentina       ARG  2015   -104800.0
# 8                       Aruba       ABW  1990         0.0
# 9                       Aruba       ABW  2000         0.0
# 10                      Aruba       ABW  2010         0.0
# 11                      Aruba       ABW  2015         0.0
# 12                  Australia       AUS  1990   -206810.0
# 13                  Australia       AUS  2000   -226800.0
# 14                  Australia       AUS  2010    709680.0
# ...

# %% [markdown]
# Slicing the rows

# %%
df6[143:147]
# Out:
#            Country Code  Year  Net change
# 143  French Guyana  NaN  1990     -4560.0
# 144  French Guyana  NaN  2000     -4290.0
# 145  French Guyana  NaN  2010     -3300.0
# 146  French Guyana  NaN  2015     -3430.0

# %% [markdown]
# Importing the values 'FRA' to column 'Code' from the above slice rows

# %%
df6.loc[143:147, ['Code']] = 'FRA'

# %% [markdown]
# Reading the DataFrame

# %%
df6
# Out:
#                       Country      Code  Year  Net change
# 0                     Algeria       DZA  1990     -8800.0
# 1                     Algeria       DZA  2000     33900.0
# 2                     Algeria       DZA  2010      7600.0
# 3                     Algeria       DZA  2015     -1400.0
# 4                   Argentina       ARG  1990   -182600.0
# 5                   Argentina       ARG  2000   -316400.0
# 6                   Argentina       ARG  2010   -223400.0
# 7                   Argentina       ARG  2015   -104800.0
# 8                       Aruba       ABW  1990         0.0
# 9                       Aruba       ABW  2000         0.0
# 10                      Aruba       ABW  2010         0.0
# 11                      Aruba       ABW  2015         0.0
# 12                  Australia       AUS  1990   -206810.0
# 13                  Australia       AUS  2000   -226800.0
# 14                  Australia       AUS  2010    709680.0
# ...

# %% [markdown]
# Checking the null values

# %%
df6.isnull().sum()
# Out:
# Country       0
# Code          0
# Year          0
# Net change    0
# dtype: int64

# %% [markdown]
# Exporting the csv file as 'cleaned forest data1.csv'

# %%
df6.to_csv('cleaned forest data1.csv',index=False)

# %% [markdown]
# Checking the csv file if there is changes or not and reading the dataFrame

# %%
import pandas as pd
fo1 = pd.read_csv('cleaned forest data1.csv')
fo1
# Out:
#                       Country      Code  Year  Net change
# 0                     Algeria       DZA  1990     -8800.0
# 1                     Algeria       DZA  2000     33900.0
# 2                     Algeria       DZA  2010      7600.0
# 3                     Algeria       DZA  2015     -1400.0
# 4                   Argentina       ARG  1990   -182600.0
# 5                   Argentina       ARG  2000   -316400.0
# 6                   Argentina       ARG  2010   -223400.0
# 7                   Argentina       ARG  2015   -104800.0
# 8                       Aruba       ABW  1990         0.0
# 9                       Aruba       ABW  2000         0.0
# 10                      Aruba       ABW  2010         0.0
# 11                      Aruba       ABW  2015         0.0
# 12                  Australia       AUS  1990   -206810.0
# 13                  Australia       AUS  2000   -226800.0
# 14                  Australia       AUS  2010    709680.0
# ...

# %% [markdown]
# Checking the null values

# %%
fo1.isnull().sum().sum()
# Out:
# 0
