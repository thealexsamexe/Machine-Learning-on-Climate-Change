# %% [markdown]
# Importing the dataset and reading the Excel file

# %%
import pandas as pd
df5 = pd.read_excel('arctic.xlsx')
df5
# Out:
#     Unnamed: 0  year  month data-type hemisphere  extent  area  rank
# 0            0  1979      9   Goddard          N    7.05  4.58  33.0
# 1            1  1980      9   Goddard          N    7.67  4.87  43.0
# 2            2  1981      9   Goddard          N    7.14  4.44  34.5
# 3            3  1982      9   Goddard          N    7.30  4.43  37.0
# 4            4  1983      9   Goddard          N    7.39  4.70  39.0
# 5            5  1984      9   Goddard          N    6.81  4.11  31.0
# 6            6  1985      9   Goddard          N    6.70  4.23  29.0
# 7            7  1986      9   Goddard          N    7.41  4.72  40.0
# 8            8  1987      9   Goddard          N    7.28  5.64  36.0
# 9            9  1988      9   Goddard          N    7.37  5.36  38.0
# 10          10  1989      9   Goddard          N    7.01  4.86  32.0
# 11          11  1990      9   Goddard          N    6.14  4.55  23.0
# 12          12  1991      9   Goddard          N    6.47  4.51  26.0
# ...

# %% [markdown]
# Droping the 'Unnamed: 0' column which occur during reading Excel file

# %%
df5.drop('Unnamed: 0',axis=1,inplace=True)

# %% [markdown]
# Reading the dataFrame

# %%
df5
# Out:
#     year  month data-type hemisphere  extent  area  rank
# 0   1979      9   Goddard          N    7.05  4.58  33.0
# 1   1980      9   Goddard          N    7.67  4.87  43.0
# 2   1981      9   Goddard          N    7.14  4.44  34.5
# 3   1982      9   Goddard          N    7.30  4.43  37.0
# 4   1983      9   Goddard          N    7.39  4.70  39.0
# 5   1984      9   Goddard          N    6.81  4.11  31.0
# 6   1985      9   Goddard          N    6.70  4.23  29.0
# 7   1986      9   Goddard          N    7.41  4.72  40.0
# 8   1987      9   Goddard          N    7.28  5.64  36.0
# 9   1988      9   Goddard          N    7.37  5.36  38.0
# 10  1989      9   Goddard          N    7.01  4.86  32.0
# 11  1990      9   Goddard          N    6.14  4.55  23.0
# 12  1991      9   Goddard          N    6.47  4.51  26.0
# 13  1992      9   Goddard          N    7.47  5.43  41.0
# 14  1993      9   Goddard          N    6.40  4.58  25.0
# ...

# %% [markdown]
# Checking the present of null values

# %%
df5.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# Exporting the csv file as 'cleaned arctic data.csv'

# %%
df5.to_csv('cleaned arctic data.csv', index = False)
